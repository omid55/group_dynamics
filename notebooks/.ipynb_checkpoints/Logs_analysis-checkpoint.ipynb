# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../src/')
# %matplotlib inline

import groupdynamics_logs_lib

# %% [markdown]
# # Helper functions

# %%
import imp
def reload():
    imp.reload(groupdynamics_logs_lib)

# %%
reload()

# %% [markdown]
# # Parameters

# %%
base_directory = '~/Datasets/GroupDynamicsData/'

# Session_304_Report_2020_01_13_17_25_15_gds100
folder_names = [
    'Session_305_Report_2020_01_14_17_44_00_gds101',
    'Session_306_Report_2020_01_18_14_44_54_gds102',
    'Session_307_Report_2020_01_18_14_44_55_gds103']

# %% [markdown]
# # Main

# %%
folder_name = folder_names[2]

directory = base_directory + folder_name
team_log = groupdynamics_logs_lib.TeamLogsLoader(directory=directory)

# %%
answers_in_simple_format = team_log.get_answers_in_simple_format()
influence_orders, influence_matrices = team_log.get_influence_matrices()


# answers_in_simple_format.to_csv('team3_answers.csv', index=False)

# %%
answers_in_simple_format
# Out:
#      Question    gds103.1's answer gds103.1's confidence gds103.2's answer  \
# 0   asbestos0               $17.00                    60                20
# 1   asbestos1                  $18                    60                20
# 2   asbestos2               $18.50                    60             18.50
# 3   asbestos3               $18.50                    70             18.50
# 4   disaster0  100 million dollars                    60            10,000
# 5   disaster1              $50,000                    70            50,000
# 6   disaster2              $75,000                    80            75,000
# 7   disaster3              $75,000                    90            75,000
# 8     school0                  0.6                    75                50
# 9     school1                  0.6                    80                .6
# 10    school2                  0.6                    90                .6
# 11    school3                  0.6                   100                .6
# 12    sports0                  0.5                    50                80
# 13    sports1                  0.5                    70
# 14    sports2                  0.6                    80                .5
# 15    sports3                  0.6                    80                .5
# 16   surgery0                  0.3                    60               .85
# 17   surgery1                  0.3                    70                .3
# 18   surgery2                  0.3                   100                .3
# 19   surgery3                  0.3                   100                .3
#
#    gds103.2's confidence
# 0                     85
# 1
# 2
# 3
# 4                    100
# 5
# 6
# 7
# 8                     75
# 9
# 10                    80
# 11
# 12                    85
# 13
# 14
# 15
# 16                    85
# 17
# 18
# 19

# %%
influence_matrices
# Out:
# array([[['60', ''],
#         ['', '100']],
#
#        [['50', '50'],
#         ['', '90']],
#
#        [['60', '40'],
#         ['', '75']],
#
#        [['50', '50'],
#         ['', '50']],
#
#        [['50', '50'],
#         ['', '50']],
#
#        [['70', '30'],
#         ['', '50']],
#
#        [['70', '30'],
#         ['', '80']],
#
#        [['60', '40'],
#         ['', '80']],
#
#        [['60', '40'],
#         ['', '80']],
#
#        [['50', '50'],
#         ['', '80']],
#
#        [['70', '30'],
#         ['30', '80']],
#
#        [['80', '20'],
#         ['', '50']],
#
#        [['100', '0'],
#         ['', '0']],
#
#        [['100', '0'],
#         ['', '0']],
#
#        [['100', '0'],
#         ['', '0']]], dtype='<U3')
