# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../src/')
# %matplotlib inline

import groupdynamics_logs_lib

# %% [markdown]
# # Helper functions

# %%
import imp
def reload():
    imp.reload(groupdynamics_logs_lib)

# %%
reload()

# %% [markdown]
# # Parameters

# %%
base_directory = '~/Datasets/GroupDynamicsData/'

# Session_304_Report_2020_01_13_17_25_15_gds100
folder_names = [
    'Session_305_Report_2020_01_14_17_44_00_gds101',
    'Session_306_Report_2020_01_18_14_44_54_gds102',
    'Session_307_Report_2020_01_18_14_44_55_gds103']

# %% [markdown]
# # Main

# %%
folder_name = folder_names[2]

directory = base_directory + folder_name
team_log = groupdynamics_logs_lib.TeamLogsLoader(directory=directory)

# %%
team_log.get_answers_in_simple_format()
# Out:
#              Question    gds103.1's answer gds103.1's confidence  \
# 0   GD_solo_asbestos0               $17.00                    60
# 1   GD_solo_asbestos1                  $18                    60
# 2   GD_solo_asbestos2               $18.50                    60
# 3   GD_solo_asbestos3               $18.50                    70
# 4   GD_solo_disaster0  100 million dollars                    60
# 5   GD_solo_disaster1              $50,000                    70
# 6   GD_solo_disaster2              $75,000                    80
# 7   GD_solo_disaster3              $75,000                    90
# 8     GD_solo_school0                  0.6                    75
# 9     GD_solo_school1                  0.6                    80
# 10    GD_solo_school2                  0.6                    90
# 11    GD_solo_school3                  0.6                   100
# 12    GD_solo_sports0                  0.5                    50
# 13    GD_solo_sports1                  0.5                    70
# 14    GD_solo_sports2                  0.6                    80
# 15    GD_solo_sports3                  0.6                    80
# 16   GD_solo_surgery0                  0.3                    60
# 17   GD_solo_surgery1                  0.3                    70
# 18   GD_solo_surgery2                  0.3                   100
# 19   GD_solo_surgery3                  0.3                   100
#
#    gds103.2's answer gds103.2's confidence
# 0                 20                    85
# 1                 20
# 2              18.50
# 3              18.50
# 4             10,000                   100
# 5             50,000
# 6             75,000
# 7             75,000
# 8                 50                    75
# 9                 .6
# 10                .6                    80
# 11                .6
# 12                80                    85
# 13
# 14                .5
# 15                .5
# 16               .85                    85
# 17                .3
# 18                .3
# 19                .3

# %%
team_log.get_influence_matrices()
# Out:
# array([[['60', ''],
#         ['', '100']],
#
#        [['50', '50'],
#         ['', '90']],
#
#        [['60', '40'],
#         ['', '75']],
#
#        [['50', '50'],
#         ['', '50']],
#
#        [['50', '50'],
#         ['', '50']],
#
#        [['70', '30'],
#         ['', '50']],
#
#        [['70', '30'],
#         ['', '80']],
#
#        [['60', '40'],
#         ['', '80']],
#
#        [['60', '40'],
#         ['', '80']],
#
#        [['50', '50'],
#         ['', '80']],
#
#        [['70', '30'],
#         ['30', '80']],
#
#        [['80', '20'],
#         ['', '50']],
#
#        [['100', '0'],
#         ['', '0']],
#
#        [['100', '0'],
#         ['', '0']],
#
#        [['100', '0'],
#         ['', '0']]], dtype='<U3')
